# %%
import pandas as pd
import json

# %%
df = pd.read_csv("files/AerodromosPrivados.csv", sep=';', encoding="utf8")
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Criado em: 2021-07-29
# ...

# %%
for i in range(len(df)):
    df.loc[i,'LATGEOPOINT'] = df.loc[i,'LATGEOPOINT'].replace(',','.')
    df.loc[i,'LONGEOPOINT'] = df.loc[i,'LONGEOPOINT'].replace(',','.')
# Out:
# <ipython-input-97-53314f3fd961>:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df.loc[i,'LATGEOPOINT'] = df.loc[i,'LATGEOPOINT'].replace(',','.')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/airports/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/airports/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/airports/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df
# Out:
#       OACI    CIAD                      Nome  \
# 0     SWZX  BA0322               Selma Nunes
# 1     SDXM  MG0474              Monte Cristo
# 2     SSLB  MS0300       Fazenda São Paulino
# 3     SDZI  BA0083         Fazenda Trijunção
# 4     SIAI  PR0042        Fazenda Esteirinha
# ...    ...     ...                       ...
# 2473  SNAJ  PA0082           Fazenda Jaguaré
# 2474  SNRJ  PA0103                    Juruti
# 2475  SIYI  GO0181         Fazenda Planalto
# 2476  SSSA  MS0329  Fazenda Sant'Anna do APA
# 2477  SSPD  MT0306           Fazenda Paraguá
#
#                              Município                  UF LATGEOPOINT  \
# 0                             MACAÚBAS               Bahia  -13.094167
# 1                           MONTE BELO        Minas Gerais  -21.363056
# 2                              CORUMBÁ  Mato Grosso do Sul  -19.025556
# 3                            JABORANDI               Bahia  -14.795278
# ...

# %%
df_OACI = df[pd.notna(df['OACI'])]

# %%
df_OACI
# Out:
#       OACI    CIAD                      Nome  \
# 0     SWZX  BA0322               Selma Nunes
# 1     SDXM  MG0474              Monte Cristo
# 2     SSLB  MS0300       Fazenda São Paulino
# 3     SDZI  BA0083         Fazenda Trijunção
# 4     SIAI  PR0042        Fazenda Esteirinha
# ...    ...     ...                       ...
# 2473  SNAJ  PA0082           Fazenda Jaguaré
# 2474  SNRJ  PA0103                    Juruti
# 2475  SIYI  GO0181         Fazenda Planalto
# 2476  SSSA  MS0329  Fazenda Sant'Anna do APA
# 2477  SSPD  MT0306           Fazenda Paraguá
#
#                              Município                  UF LATGEOPOINT  \
# 0                             MACAÚBAS               Bahia  -13.094167
# 1                           MONTE BELO        Minas Gerais  -21.363056
# 2                              CORUMBÁ  Mato Grosso do Sul  -19.025556
# 3                            JABORANDI               Bahia  -14.795278
# ...

# %%
#df_OACI.set_index("OACI", inplace=True)
#df_OACI

# %%
goias = df_OACI[df_OACI['UF'] == 'Goiás']

# %%
goias
# Out:
#       OACI    CIAD                                             Nome  \
# 10    SBOR  GO0290                            Fazenda AgroTamareira
# 16    SNLL  GO0191                               Condomínio Liberty
# 31    SITR  GO0056                                 Fazenda Tamboril
# 36    SNLQ  GO0100                                 Fazenda Conforto
# 37    SSGR  GO0218  Regional de Santa Helena de Goiás - Paulo Lopes
# ...    ...     ...                                              ...
# 2432  SWAV  GO0116                          Fazenda Vale dos Sonhos
# 2449  SWDT  GO0118                                          Dezoito
# 2452  SDLW  GO0040                                 Fazenda Colorado
# 2459  SWBY  GO0117                               Fazenda Bela Vista
# 2475  SIYI  GO0181                                Fazenda Planalto
#
#                   Município     UF LATGEOPOINT LONGEOPOINT      Latitude  \
# 10               MUNDO NOVO  Goiás  -13.730278  -50.358056  13°43'49.0"S
# ...

# %%
goias.to_json("files/goias_private.json",orient="records", force_ascii=False)
